# %%
import numpy as np
import pandas as pd
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# %%
from google.colab import files
Upload = files.upload()
# Out:
#      <input type="file" id="files-24965b6e-5f64-455b-9b42-ffff230d5fc1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-24965b6e-5f64-455b-9b42-ffff230d5fc1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
email_spam = pd.read_csv("enron_mail_spam_dataset.csv")
email_spam = shuffle(email_spam)
email_spam
# Out:
#      Category                                            Message
# 5162      ham               Just send a text. We'll skype later.
# 3742     spam                                      2/2 146tf150p
# 2835      ham                      U sick still can go shopping?
# 2572      ham  … and don‘t worry we‘ll have finished by march...
# 3778     spam  Mila, age23, blonde, new in UK. I look sex wit...
# ...       ...                                                ...
# 3530     spam  Xmas & New Years Eve tickets are now on sale f...
# 2729     spam  Urgent Please call 09066612661 from landline. ...
# 5265      ham                         Gud ni8.swt drms.take care
# 1153      ham                             Ok i go change also...
# 2058      ham            Nothing, i got msg frm tht unknown no..
#
# [5572 rows x 2 columns]

# %%
email_spam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5572 entries, 5162 to 2058
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Category  5572 non-null   object
#  1   Message   5572 non-null   object
# dtypes: object(2)
# memory usage: 130.6+ KB

# %%
email_spam.shape
# Out:
# (5572, 2)

# %%
# reshaping data with binary results
email_spam.loc[email_spam["Category"]=="spam" , "Category" ,] = 0
email_spam.loc[email_spam["Category"]=="ham"  , "Category" ,] = 1

# splitting data into labels and messages
X = email_spam["Message"]
Y = email_spam["Category"]

# %%
email_spam
# Out:
#      Category                                            Message
# 5162        1               Just send a text. We'll skype later.
# 3742        0                                      2/2 146tf150p
# 2835        1                      U sick still can go shopping?
# 2572        1  … and don‘t worry we‘ll have finished by march...
# 3778        0  Mila, age23, blonde, new in UK. I look sex wit...
# ...       ...                                                ...
# 3530        0  Xmas & New Years Eve tickets are now on sale f...
# 2729        0  Urgent Please call 09066612661 from landline. ...
# 5265        1                         Gud ni8.swt drms.take care
# 1153        1                             Ok i go change also...
# 2058        1            Nothing, i got msg frm tht unknown no..
#
# [5572 rows x 2 columns]

# %%
# split data into train and test to check the model
X_train , X_test , Y_train , Y_test = train_test_split(X, Y, test_size=0.2, random_state=3)

# feature extraction data
feature_extraction = TfidfVectorizer(min_df=1 , stop_words="english")

# %%
X_train_feature = feature_extraction.fit_transform(X_train)
X_test_feature  = feature_extraction.transform(X_test)
Y_train         = Y_train.astype("int")
Y_test          = Y_test.astype("int")

# %%
# perfect model for this is SVC (Support Vector Classification)
# which is apply on binary data
SVC_Model = SVC(kernel='linear' , C=1)
SVC_Model.fit(X_train_feature , Y_train)

# %%
# train accuracy
Train_Prediction = SVC_Model.predict(X_train_feature)
SVC_Model_Train_Accuracy = accuracy_score(Y_train , Train_Prediction)
SVC_Model_Train_Accuracy
# Out:
# 0.9968588736818488

# %%
# test accuracy
Test_Prediction = SVC_Model.predict(X_test_feature)
SVC_Model_Test_Accuracy = accuracy_score(Y_test , Test_Prediction)
SVC_Model_Test_Accuracy
# Out:
# 0.9856502242152466
