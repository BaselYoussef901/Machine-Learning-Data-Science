# %% [markdown]
# # `Github Link`: https://github.com/BaselYoussef901?tab=repositories
# ## @Author: *Basel Youssef*
# >> some notes and points down at the end will help you to run this program [don't forget to check it.]

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# dataset_url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/Data%20Files/historical_automobile_sales.csv"
cars_df = pd.read_csv('historical_automobile_sales.csv')
cars_df
# Out:
#            Date  Year Month  Recession  Consumer_Confidence
# 0     1/31/1980  1980   Jan          1               108.24  \
# 1     2/29/1980  1980   Feb          1                98.75
# 2     3/31/1980  1980   Mar          1               107.48
# 3     4/30/1980  1980   Apr          1               115.01
# 4     5/31/1980  1980   May          1                98.72
# ..          ...   ...   ...        ...                  ...
# 523   8/31/2023  2023   Aug          0               103.36
# 524   9/30/2023  2023   Sep          0               101.55
# 525  10/31/2023  2023   Oct          0               124.66
# 526  11/30/2023  2023   Nov          0                97.09
# 527  12/31/2023  2023   Dec          0                95.92
#
#      Seasonality_Weight      Price  Advertising_Expenditure  Competition
# 0                  0.50  27483.571                     1558            7  \
# 1                  0.75  24308.678                     3048            4
# ...

# %% [markdown]
# # **Task 1.1**
# Develop a *Line chart* using the functionality of pandas to show how automobile sales fluctuate from year to year.

# %%
plt.figure(figsize=(12,6))
plt.plot(cars_df['Year'], cars_df['Price'], marker='o', color='b')
plt.title('Automobile Sales over the Years')
plt.xlabel('Year')
plt.ylabel('Price')


plt.show()

# %% [markdown]
# # **Task 1.2**
# Plot different lines for categories of `Vehicle Type` and analyse the trend to answer the question "Is there a noticeable difference in sales trends between different vehicle types during recession periods?

# %%
plt.figure(figsize=(15,6))
for V_Type in cars_df['Vehicle_Type'].unique():
    for is_recession in [True,False]:
        data = cars_df[ (cars_df['Vehicle_Type'] == V_Type) & (cars_df['Recession'] == is_recession) ]
        label = f'{V_Type} (Recession)' if is_recession else f'{V_Type} (Non-Recession)'
        linestyle = '-' if is_recession else '--'
        plt.plot(data['Year'] , data['Price'] , marker='o' , linestyle=linestyle , label=label)

plt.title('Sales Trends by Vehicle Type During Recession Periods')
plt.xlabel('Year')
plt.ylabel('Sales')
plt.legend()
plt.show()

# %% [markdown]
# # **Task 1.3**
# Use the functionality of Seaborn Library to create a visualization to compare the sales trend per vehicle type for a recession period with a non-recession period.

# %%
import seaborn as sns
sns.set_style("whitegrid")
plt.figure(figsize=(12, 6))
sns.lineplot(data=cars_df, x='Year', y='Price', hue='Vehicle_Type', style='Recession', markers=True, dashes=False)
plt.title('Sales Trend Comparison (Recession vs. Non-Recession)')
plt.xlabel('Year')
plt.ylabel('Sales')
plt.legend(title='Recession', loc='upper right')
plt.show()

# %% [markdown]
# # **Task 1.4**
#  Use sub plotting to compare the variations in GDP during recession and non-recession period by developing line plots for each period

# %%
fig, axs = plt.subplots(2, 1, figsize=(10, 8), sharex=True)
# Plot for recession period
recession_data = cars_df[cars_df['Recession'] == 1]
axs[0].plot(recession_data['Year'], recession_data['GDP'], marker='o', linestyle='-', color='red')
axs[0].set_title('GDP Variation During Recession Period')
axs[0].set_ylabel('GDP')
axs[0].grid(True)

# Plot for non-recession period
non_recession_data = cars_df[cars_df['Recession'] == 0]
axs[1].plot(non_recession_data['Year'], non_recession_data['GDP'], marker='o', linestyle='-', color='green')
axs[1].set_title('GDP Variation During Non-Recession Period')
axs[1].set_xlabel('Year')
axs[1].set_ylabel('GDP')
axs[1].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # **Task 1.5**
# Develop a Bubble plot for displaying the impact of seasonality on Automobile Sales

# %%
# Assign colors to each month (optional)
colors = ['red', 'orange', 'yellow', 'green', 'blue', 'purple', 'pink', 'brown', 'gray', 'cyan', 'magenta', 'black']
#bubble_size = [s*10 for s in cars_df['Price']]


from matplotlib.cm import get_cmap
cmap = get_cmap('tab20c', 528)
normalized_prices = (cars_df['Price'] - cars_df['Price'].min()) / (cars_df['Price'].max() - cars_df['Price'].min())

plt.figure(figsize=(12, 6))
plt.scatter(cars_df.index, cars_df['Month'], s=100, c=cmap(normalized_prices), alpha=0.7, edgecolors='k', linewidths=1)

plt.title('Impact of Seasonality on Automobile Sales')
plt.xlabel('Months')
plt.ylabel('Sales')
plt.grid(True)
plt.xticks(cars_df.index, cars_df['Month'] , rotation=90) 

plt.show()

# %% [markdown]
# # **Task 1.6**
# Use the functionality of Matplotlib to develop a scatter plot to identify the correlation between average vehicle price relate to the sales volume during recessions

# %%
recession_data = cars_df[cars_df['Recession']==1]

# Create a scatter plot to identify the correlation between price and sales during recessions
plt.figure(figsize=(10, 6))
plt.scatter(recession_data['Price'], recession_data['Price'], c='y', label='Recession Years', marker='o')

# Customize the plot
plt.title('Correlation Between Average Vehicle Price and Sales During Recessions')
plt.xlabel('Average Vehicle Price')
plt.ylabel('Prices Volume')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# # **Task 1.7**
# Create a pie chart to display the portion of advertising expenditure of XYZAutomotives during recession and non-recession periods

# %%
# Calculate total expenditure during recession and non-recession periods
total_recession_expenditure = cars_df[cars_df['Recession']==1]['Advertising_Expenditure'].sum()
total_non_recession_expenditure = cars_df[cars_df['Recession']==0]['Advertising_Expenditure'].sum()

# Create data for the pie chart
expenditure_data = [total_recession_expenditure, total_non_recession_expenditure]
labels = ['Recession', 'Non-Recession']
colors = ['yellow', 'cyan']
explode = (0.1, 0)  # Explode the first slice (Recession)

# Create the pie chart
plt.figure(figsize=(5, 5))
plt.pie(expenditure_data, labels=labels, colors=colors, explode=explode, autopct='%1.1f%%', startangle=140)

plt.title('Advertising Expenditure of XYZAutomotives During Recession and Non-Recession Periods')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# # **Task 1.8**
# Develop a pie chart to display the total Advertisement expenditure for each vehicle type during recession period

# %%
recession_data = cars_df[cars_df['Recession']==1]
total_expenditure_by_type = recession_data.groupby('Vehicle_Type')['Advertising_Expenditure'].sum()
expenditure_data = total_expenditure_by_type.values
labels = total_expenditure_by_type.index
colors = ['gray' , 'cyan', 'pink', 'orange' , 'yellow']  # You can add more colors as needed

# Create the pie chart
plt.figure(figsize=(5, 5))
plt.pie(expenditure_data, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)

plt.title('Total Advertisement Expenditure by Vehicle Type During Recession')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# # **Task 1.9**
# Develop a countplot to analyse the effect of the unemployment rate on vehicle type and sales during the Recession Period.

# %%
recession_data = cars_df[cars_df['Recession']==1]

sns.set_style("whitegrid")
plt.figure(figsize=(10, 6))
sns.countplot(data=recession_data, x='Vehicle_Type', hue='unemployment_rate', palette='coolwarm')

# Customize the plot
plt.title('Effect of Unemployment Rate on Vehicle Type and Sales During Recession')
plt.xlabel('Vehicle Type')
plt.ylabel('Count')
plt.legend(title='Unemployment Rate', loc='upper right')

# %% [markdown]
# Starting Now With Part 2 of the Assignment...

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import plotly.express as px  # Assuming you're using Plotly for plotting
# Out:
# C:\Users\007\AppData\Local\Temp\ipykernel_8312\3382579209.py:2: UserWarning:
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#   import dash_core_components as dcc
# C:\Users\007\AppData\Local\Temp\ipykernel_8312\3382579209.py:3: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   import dash_html_components as html

# %%
app = dash.Dash(__name__)

# %% [markdown]
# # **Task 2.1**
# Create a Dash application and give it a meaningful title

# %%
app.layout = html.Div([
    html.H1('My Dash Application', style={'textAlign': 'center'}),
    dcc.Graph(id='example-graph'),
    # Add more components here as needed
])

# %%
if __name__ == '__main__':
    app.run_server(debug=True)

#under this there's a "My Dash Application" with black color in case you don't see it.

# %% [markdown]
# if the above plot doesn't work with you go on your browser and paste 'http://127.0.0.1:8050/'
# **How it works:**
# you can do zoom in and out from top right.
# same yo your mouse.

# %% [markdown]
# # **Task 2.2 & 2.3**
#  -Add drop-downs to your dashboard with appropriate titles and options.
#
#  -Add a division for output display with appropriate 'id' and 'classname' property

# %%
app.layout = html.Div([
    html.H1('My Dash Application', style={'textAlign': 'center'}),
    
    # Dropdown for selecting a vehicle type
    html.Div([
        html.Label('Select Vehicle Type:'),
        dcc.Dropdown(
            id='vehicle-type-dropdown',
            options=[
                {'label': 'Sports', 'value': 'Sports'},
                {'label': 'Small Family Car', 'value': 'Smallfamiliycar'},
                {'label': 'Super Mini-Car', 'value': 'Supperminicar'},
                {'label': 'Executive Car', 'value': 'Executivecar'},
                {'label': 'Medium Family Car', 'value': 'Mediumfamilycar'},
            ],
            value='Smallfamiliycar'  # Default selected value
        ),
    ], style={'width': '30%', 'display': 'inline-block'}),
    
    # Dropdown for selecting a year
    html.Div([
        html.Label('Select Year:'),
        dcc.Dropdown(
            id='year-dropdown',
            options=[
                {'label': '2001', 'value': 2001},
                {'label': '2002', 'value': 2002},
                {'label': '2003', 'value': 2003},
                {'label': '2004', 'value': 2004},
                {'label': '2005', 'value': 2005},
                {'label': '2006', 'value': 2006},
                {'label': '2007', 'value': 2007},
                {'label': '2008', 'value': 2008},
                {'label': '2009', 'value': 2009},
                {'label': '2010', 'value': 2010},
                {'label': '2011', 'value': 2011},
                {'label': '2012', 'value': 2012},
                {'label': '2013', 'value': 2013},
                {'label': '2014', 'value': 2014},
                {'label': '2015', 'value': 2015},
                {'label': '2016', 'value': 2016},
                {'label': '2017', 'value': 2017},
                {'label': '2018', 'value': 2018},
                {'label': '2019', 'value': 2019},
                {'label': '2020', 'value': 2020},
                {'label': '2021', 'value': 2021},
                {'label': '2022', 'value': 2022},
                {'label': '2023', 'value': 2023},
                # Add more year options as needed
            ],
            value=2001  # Default selected value
        ),
    ], style={'width': '30%', 'display': 'inline-block'}),
    
    #Division for output display                        [Task 2.3]
    html.Div(
        id='output-display',
        className='output-style',
        children = [
            dcc.Graph(id='sales-plot'),
        ]
    ),
    
    # Add more components here as needed
])

# %%
if __name__ == '__main__':
    app.run_server(debug=True)

# %% [markdown]
# # **Task 2.4**
# Creating Callbacks; Define the callback function to update the input container

# %%
# Define a callback to update the plot based on user input
@app.callback(
    Output('sales-plot', 'figure'),
    Input('vehicle-type-dropdown', 'value'),
    Input('year-dropdown', 'value')
)
def update_plot(selected_vehicle_type, selected_year):
    # Filter the DataFrame based on the selected vehicle type and year
    filtered_df = cars_df[(cars_df['Vehicle_Type'] == selected_vehicle_type) & (cars_df['Year'] == selected_year)]

    # Create a plot using Plotly Express (you can use your preferred plotting library)
    fig = px.bar(filtered_df, x='Year', y='Sales', title=f'Sales for {selected_vehicle_type} in {selected_year}')
    
    return fig

# %%
if __name__ == '__main__':
    app.run_server(debug=True)

# %% [markdown]
# # **Task 2.5**
# Create and display graphs for Recession Report Statistics

# %%
app.layout = html.Div([
    html.H1('Recession Report Statistics' , style={'textAlign': 'center'}),
    # Dropdown for selecting a statistic
    dcc.Dropdown(
        id = 'statistic-dropdown',
        options=[
            {'label': 'GDP (Billions)', 'value': 'GDP'},
            {'label': 'Unemployment Rate (%)', 'value': 'unemployment_rate'},
            {'label': 'Growth Rate (%)', 'value': 'Growth_Rate'},
            {'label': 'Consumer Confidence', 'value': 'Consumer_Confidence'},
        ],
        value='GDP'  # Default selected value
    ),

    # Line chart for the selected statistic
    dcc.Graph(id='line-chart'),
    
    # Bar chart for recession statistics
    dcc.Graph(id='bar-chart')
])

# %%
# Define a callback to update the line chart based on the selected statistic
@app.callback(
    Output('line-chart', 'figure'),
    Input('statistic-dropdown', 'value')
)
def update_line_chart(selected_statistic):
    fig = px.line(cars_df, x='Year', y=selected_statistic, title=f'{selected_statistic} Over Time')
    return fig

# %%
# Define a callback to update the bar chart for recession statistics
@app.callback(
    Output('bar-chart', 'figure'),
    Input('statistic-dropdown', 'value')
)
def update_bar_chart(selected_statistic):
    recession_data = cars_df[cars_df['Recession']==1]
    fig = px.bar(recession_data, x='Year', y=selected_statistic, title=f'{selected_statistic} During Recession Years')
    return fig

# %%
if __name__ == '__main__':
    app.run_server(debug=True)

# %% [markdown]
# ## **Task 2.6**
# Create and display graphs for Yearly Report Statistics

# %% [markdown]
# **Making our Yearly Data**

# %%
# Yearly Total Profit
Yearly_Total_Profit = cars_df.groupby('Year')['Price'].sum().reset_index()

# Yearly Total Sold Cars
Yearly_Total_Sold_Cars = cars_df.groupby('Year')['Automobile_Sales'].sum().reset_index()

# Yearly Total Advertising
Yearly_Total_Advertising = cars_df.groupby('Year')['Advertising_Expenditure'].sum().reset_index()


# Yearly Total Competition
Yearly_Total_Competition = cars_df.groupby('Year')['Competition'].sum().reset_index()

# Yearly Buying City
total_city_buying_year = cars_df.groupby(['Year' , 'City']).size().reset_index(name='Total Buying')
yearly_total_buying_cities = total_city_buying_year.groupby(['Year' , 'City'])['Total Buying'].idxmax()
unique_years_with_highest_buying_city = total_city_buying_year.loc[yearly_total_buying_cities]
years_with_highest_buying_city = unique_years_with_highest_buying_city.sort_values(by=['Year', 'Total Buying'], ascending=[True, False])
Yearly_Buying_City = years_with_highest_buying_city.drop_duplicates(subset='Year').reset_index()
Yearly_Buying_City = Yearly_Buying_City.drop('index' , axis=1)


Yearly_Buying_City
# Out:
#     Year        City  Total Buying
# 0   1980    New York             5
# 1   1981  California             5
# 2   1982    New York             4
# 3   1983    Illinois             5
# 4   1984    New York             6
# 5   1985     Georgia             6
# 6   1986  California             4
# 7   1987     Georgia             4
# 8   1988    New York             6
# 9   1989     Georgia             5
# 10  1990  California             5
# 11  1991    New York             5
# 12  1992     Georgia             6
# 13  1993  California             5
# 14  1994    Illinois             4
# 15  1995    New York             6
# 16  1996     Georgia             5
# 17  1997  California             4
# 18  1998    Illinois             6
# 19  1999    New York             7
# 20  2000     Georgia             5
# 21  2001     Georgia             5
# 22  2002  California             5
# 23  2003     Georgia             5
# 24  2004  California             6
# 25  2005     Georgia             4
# ...

# %%
app.layout = html.Div([
    html.H1('Yearly Report Statistics', style={'textAlign': 'center'}),
    
    # Dropdown for selecting a statistic
    dcc.Dropdown(
        id='statistic-dropdown',
        options=[
            {'label': 'Yearly Profit', 'value': 'Price'},
            {'label': 'Yearly Sold Cars', 'value': 'Automobile_Sales'},
            {'label': 'Yearly Advertising', 'value': 'Advertising_Expenditure'},
            {'label': 'Yearly Competition', 'value': 'Competition'},
            #{'label': 'Yearly Buying City', 'value': 'Yearly_Buying_City'},
        ],
        value='Price'  # Default selected value
    ),
    
    # Line chart for the selected statistic
    dcc.Graph(id='line-chart'),
    
    # Bar chart for yearly statistics
    dcc.Graph(id='bar-chart')
])

# %%
# Define a callback to update the line chart based on the selected statistic
@app.callback(
    Output('line-chart', 'figure'),
    Input('statistic-dropdown', 'value')
)
def update_line_chart(selected_statistic):
    Data = Yearly_Total_Profit
    if selected_statistic == 'Price':
        Data = Yearly_Total_Profit

    if selected_statistic == 'Automobile_Sales':
        Data = Yearly_Total_Sold_Cars

    if selected_statistic == 'Advertising_Expenditure':
        Data = Yearly_Total_Advertising

    if selected_statistic == 'Competition':
        Data = Yearly_Total_Competition

    fig = px.line(Data, x='Year', y=selected_statistic, title=f'{selected_statistic} Over Years')
    return fig

# %%
# Define a callback to update the bar chart for yearly statistics
@app.callback(
    Output('bar-chart', 'figure'),
    Input('statistic-dropdown', 'value')
)
def update_bar_chart(selected_statistic):
    Data = Yearly_Total_Profit
    if selected_statistic == 'Price':
        Data = Yearly_Total_Profit

    if selected_statistic == 'Automobile_Sales':
        Data = Yearly_Total_Sold_Cars

    if selected_statistic == 'Advertising_Expenditure':
        Data = Yearly_Total_Advertising

    if selected_statistic == 'Competition':
        Data = Yearly_Total_Competition

    fig = px.bar(Data, x='Year', y=selected_statistic, title=f'{selected_statistic} Over Years')
    return fig

# %%
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File c:\Users\007\AppData\Local\Programs\Python\Python39\lib\site-packages\plotly\express\_chart_types.py:373, in bar(
#     data_frame=    Year       Price
# 0   1980  317757.318
# 1   19...960.556
# 42  2022  279378.727
# 43  2023  275042.063,
#     x='Year',
#     y='Price',
#     color=None,
#     pattern_shape=None,
#     facet_row=None,
#     facet_col=None,
#     facet_col_wrap=0,
#     facet_row_spacing=None,
#     facet_col_spacing=None,
#     hover_name=None,
#     hover_data=None,
#     custom_data=None,
#     text=None,
#     base=None,
#     error_x=None,
#     error_x_minus=None,
#     error_y=None,
# ...

# %% [markdown]
# # **Some Points to be knows**
# 1. Dash Boards all work but first run will give you an error just because there is no initial value to it, but u can easily use it and all will work fine after you choose from the dropdown list anything both line-bar works fine.
# 2. I'm newbie using Dashboard so don't be judgy of bad code sectors or implementation
# 3. if using Jupyter idk how to stop the Dashboard from running so you have to Restart jupyter and run only first two cells `(imports and data)` and two cells where `Part 2 of Assigment` start (imports and app)
# 4. only run the specific cells you want, like if you want to see board of Task 2.5, After you run the pervious cells in **Point 3** Run the Task 2.5 Cells only (all the cells).
# 5. This Code all written by me Check it on Github in: `IBM-Data-Science-Course` , Author (user): `@BaselYoussef901` on Github, LinkedIn , Twitter.
#
# Thank You,
# Basel Youssef.
